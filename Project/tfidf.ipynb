# %%
import pandas as pd
from urllib.parse import urlparse
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.text import tokenizer_from_json
import json
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('data/data.csv')
data['agent'] = data['URLs'].apply(lambda x: urlparse(x)[1])

headlines = data['Headline'].tolist()
labels = data['Label'].tolist()

# %%
headlines
# Out:
# ['Four ways Bob Corker skewered Donald Trump',
#  "Linklater's war veteran comedy speaks to modern America, says star",
#  'Trump’s Fight With Corker Jeopardizes His Legislative Agenda',
#  "Egypt's Cheiron wins tie-up with Pemex for Mexican onshore oil field",
#  "Jason Aldean opens 'SNL' with Vegas tribute",
#  'JetNation FanDuel League; Week 4',
#  'Kansas Tried a Tax Plan Similar to Trump’s. It Failed.',
#  'India RBI chief: growth important, but not at cost of inflation - newspaper',
#  'EPA chief to sign rule on Clean Power Plan exit on Tuesday',
#  'Talks on sale of Air Berlin planes to easyJet at risk of collapse: report',
#  'U.S. President Donald Trump Quietly Signs Law To Allow Warrantless Searches In Parts Of VA, DC and MD',
#  '2017 Fantasy Football Team Defense Rankings - Week 5',
#  'Just Shut Up & Play Some Damn Baseball!!',
#  'Deloitte cyber attack affected up to 350 clients: Guardian',
# ...

# %%
with open('./data/bow.json') as f:
    _bow = json.load(f)

# %%
BOW = tokenizer_from_json(_bow)

# %%
BOW.texts_to_sequences(['Four ways Bob Corker skewered Donald Trump', "Linklater's war veteran comedy speaks to modern America, says star"])
# Out:
# [[270, 1713, 253, 402, 4436, 85, 8],
#  [2818, 91, 948, 1714, 2819, 1, 1397, 224, 22, 376]]

# %%
BOW.index_word
# Out:
# {1: 'to',
#  2: 'the',
#  3: 'in',
#  4: 'of',
#  5: 'for',
#  6: 'a',
#  7: 'on',
#  8: 'trump',
#  9: 'and',
#  10: 'with',
#  11: 'is',
#  12: 'week',
#  13: '2017',
#  14: '10',
#  15: 'vegas',
#  16: 'at',
#  17: 'as',
#  18: 'after',
#  19: 'from',
#  20: '5',
#  21: 'new',
#  22: 'says',
#  23: 'game',
#  24: 'u',
#  25: 'las',
#  26: 's',
#  27: 'more',
#  28: 'football',
#  29: 'by',
#  30: 'be',
#  31: '4',
#  32: 'over',
#  33: 'win',
#  34: 'shooting',
#  35: 'up',
#  36: '1',
#  37: 'rankings',
#  38: 'are',
#  39: 'it',
#  40: 'fantasy',
#  41: 'hbd',
#  42: 'video',
#  43: 'us',
#  44: 'about',
#  45: 'out',
#  46: 'how',
#  47: '9',
#  48: 'weinstein',
#  49: 'world',
#  50: 'will',
#  51: 'police',
#  52: 'puerto',
#  53: 'what',
#  54: 'not',
#  55: 'his',
#  56: 'president',
#  57: 'you',
#  58: 'was',
#  59: '3',
#  60: 'has',
#  61: 'ravens',
#  62: '2',
#  63: 'stories',
#  64: 'who',
#  65: 'top',
#  66: 'season',
#  67: 'deal',
#  68: 'era',
#  69: 'cup',
# ...

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import
# Out:
# ['Four ways Bob Corker skewered Donald Trump',
#  "Linklater's war veteran comedy speaks to modern America, says star",
#  'Trump’s Fight With Corker Jeopardizes His Legislative Agenda',
#  "Egypt's Cheiron wins tie-up with Pemex for Mexican onshore oil field",
#  "Jason Aldean opens 'SNL' with Vegas tribute",
#  'JetNation FanDuel League; Week 4',
#  'Kansas Tried a Tax Plan Similar to Trump’s. It Failed.',
#  'India RBI chief: growth important, but not at cost of inflation - newspaper',
#  'EPA chief to sign rule on Clean Power Plan exit on Tuesday',
#  'Talks on sale of Air Berlin planes to easyJet at risk of collapse: report',
#  'U.S. President Donald Trump Quietly Signs Law To Allow Warrantless Searches In Parts Of VA, DC and MD',
#  '2017 Fantasy Football Team Defense Rankings - Week 5',
#  'Just Shut Up & Play Some Damn Baseball!!',
#  'Deloitte cyber attack affected up to 350 clients: Guardian',
# ...
